# %%
import constants
from alpaca.trading.client import TradingClient
from datetime import datetime, time as dt_time

api_key = constants.ALPACA_API_KEY3
secret_key = constants.ALPACA_SECRET_KEY3

# %%
trading_client = TradingClient(api_key=api_key, secret_key=secret_key, paper=True)

# %%
print(trading_client.get_account())
# Out:
# id=UUID('958eb7cb-6749-41ca-ad58-27111f43cfb7') account_number='PA3XPU4MENR5' status=<AccountStatus.ACTIVE: 'ACTIVE'> crypto_status=<AccountStatus.ACTIVE: 'ACTIVE'> currency='USD' buying_power='60000' regt_buying_power='60000' daytrading_buying_power='0' non_marginable_buying_power='30000' cash='30000' accrued_fees='0' pending_transfer_out=None pending_transfer_in='0' portfolio_value='30000' pattern_day_trader=False trading_blocked=False transfers_blocked=False account_blocked=False created_at=datetime.datetime(2024, 6, 27, 11, 23, 24, 743315, tzinfo=TzInfo(UTC)) trade_suspended_by_user=False multiplier='2' shorting_enabled=True equity='30000' last_equity='30000' long_market_value='0' short_market_value='0' initial_margin='0' maintenance_margin='0' last_maintenance_margin='0' sma='30000' daytrade_count=0 options_buying_power='30000' options_approved_level=2 options_trading_level=2

# %%
print(trading_client.get_clock())
# Out:
# timestamp=datetime.datetime(2024, 7, 18, 2, 22, 36, 63790, tzinfo=TzInfo(-04:00)) is_open=False next_open=datetime.datetime(2024, 7, 18, 9, 30, tzinfo=TzInfo(-04:00)) next_close=datetime.datetime(2024, 7, 18, 16, 0, tzinfo=TzInfo(-04:00))

# %%
now = datetime.now();
print(dt_time(3,30) <= now.time() < dt_time(3,40))
# Out:
# False
